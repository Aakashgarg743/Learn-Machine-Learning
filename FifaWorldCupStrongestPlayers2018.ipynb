# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline
df = pd.read_csv("wc2018-players.csv")
df.head(10)
# Out:
#         Team   # Pos.   FIFA Popular Name  Birth Date  Shirt Name  \
# 0  Argentina   3   DF  TAGLIAFICO Nicolas  31.08.1992  TAGLIAFICO
# 1  Argentina  22   MF      PAVON Cristian  21.01.1996       PAVÓN
# 2  Argentina  15   MF      LANZINI Manuel  15.02.1993     LANZINI
# 3  Argentina  18   DF      SALVIO Eduardo  13.07.1990      SALVIO
# 4  Argentina  10   FW        MESSI Lionel  24.06.1987       MESSI
# 5  Argentina   4   DF    ANSALDI Cristian  20.09.1986     ANSALDI
# 6  Argentina   5   MF        BIGLIA Lucas  30.01.1986      BIGLIA
# 7  Argentina   7   MF         BANEGA Ever  29.06.1988      BANEGA
# 8  Argentina  14   DF   MASCHERANO Javier  08.06.1984  MASCHERANO
# 9  Argentina  21   FW        DYBALA Paulo  15.11.1993      DYBALA
#
#                            Club  Height  Weight
# 0                AFC Ajax (NED)     169      65
# 1         CA Boca Juniors (ARG)     169      65
# 2      West Ham United FC (ENG)     167      66
# ...

# %%
df.tail(10)
# Out:
#         Team   # Pos.   FIFA Popular Name  Birth Date    Shirt Name  \
# 726  Uruguay   2   DF        GIMENEZ Jose  20.01.1995  J.M. GIMENEZ
# 727  Uruguay  11   FW    STUANI Cristhian  12.10.1986        STUANI
# 728  Uruguay  21   FW      CAVANI Edinson  14.02.1987        CAVANI
# 729  Uruguay   7   MF  RODRIGUEZ Cristian  30.09.1985  C. RODRIGUEZ
# 730  Uruguay  12   GK      CAMPANA Martin  29.05.1989       CAMPAÑA
# 731  Uruguay  15   MF       VECINO Matias  24.08.1991        VECINO
# 732  Uruguay  23   GK        SILVA Martin  25.03.1983      M. SILVA
# 733  Uruguay   9   FW         SUAREZ Luis  24.01.1987        SUAREZ
# 734  Uruguay  18   FW   GOMEZ Maximiliano  14.08.1996      M. GOMEZ
# 735  Uruguay  19   DF    COATES Sebastian  07.10.1990        COATES
#
#                              Club  Height  Weight
# 726         Atletico Madrid (ESP)     185      77
# 727               Girona FC (ESP)     186      78
# 728  Paris Saint-Germain FC (FRA)     188      78
# ...

# %%
del df["#"]
df.head(10)
# Out:
#         Team Pos.   FIFA Popular Name  Birth Date  Shirt Name  \
# 0  Argentina   DF  TAGLIAFICO Nicolas  31.08.1992  TAGLIAFICO
# 1  Argentina   MF      PAVON Cristian  21.01.1996       PAVÓN
# 2  Argentina   MF      LANZINI Manuel  15.02.1993     LANZINI
# 3  Argentina   DF      SALVIO Eduardo  13.07.1990      SALVIO
# 4  Argentina   FW        MESSI Lionel  24.06.1987       MESSI
# 5  Argentina   DF    ANSALDI Cristian  20.09.1986     ANSALDI
# 6  Argentina   MF        BIGLIA Lucas  30.01.1986      BIGLIA
# 7  Argentina   MF         BANEGA Ever  29.06.1988      BANEGA
# 8  Argentina   DF   MASCHERANO Javier  08.06.1984  MASCHERANO
# 9  Argentina   FW        DYBALA Paulo  15.11.1993      DYBALA
#
#                            Club  Height  Weight
# 0                AFC Ajax (NED)     169      65
# 1         CA Boca Juniors (ARG)     169      65
# 2      West Ham United FC (ENG)     167      66
# 3              SL Benfica (POR)     167      69
# ...

# %%
plt.figure(figsize=(15,100))
sb.countplot(y= df.Club, palette="Set2")
# Out:
# <AxesSubplot:xlabel='count', ylabel='Club'>

# %%
df.head(79)
# Out:
#          Team Pos.   FIFA Popular Name  Birth Date   Shirt Name  \
# 0   Argentina   DF  TAGLIAFICO Nicolas  31.08.1992   TAGLIAFICO
# 1   Argentina   MF      PAVON Cristian  21.01.1996        PAVÓN
# 2   Argentina   MF      LANZINI Manuel  15.02.1993      LANZINI
# 3   Argentina   DF      SALVIO Eduardo  13.07.1990       SALVIO
# 4   Argentina   FW        MESSI Lionel  24.06.1987        MESSI
# ..        ...  ...                 ...         ...          ...
# 74     Brazil   MF   PHILIPPE COUTINHO  12.06.1992  P. COUTINHO
# 75     Brazil   FW       DOUGLAS COSTA  14.09.1990     D. COSTA
# 76     Brazil   DF         FILIPE LUIS  09.08.1985  FILIPE LUIS
# 77     Brazil   FW       GABRIEL JESUS  03.04.1997     G. JESUS
# 78     Brazil   DF          MARQUINHOS  14.05.1994   MARQUINHOS
#
#                             Club  Height  Weight
# 0                 AFC Ajax (NED)     169      65
# 1          CA Boca Juniors (ARG)     169      65
# ...

# %%
plt.figure(figsize=(15,6))
sb.countplot(x=df.Height, palette="Set2")
# Out:
# <AxesSubplot:xlabel='Height', ylabel='count'>
